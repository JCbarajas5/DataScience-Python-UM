# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets
pop_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_Mexican_states_by_population_density')[0]
pop_df.set_index('State', inplace=True) 
pop_df.drop('Rank', axis=1, inplace=True) 

gdp_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_Mexican_states_by_GDP')[0]
gdp_df.columns = gdp_df.columns.droplevel(0)
gdp_df.set_index('State', inplace=True)

# %%
# Merge the datasets
merged_df = pd.merge(pop_df, gdp_df, on='State')

# Sort by population density and select the top 10 states
top_30_pop = merged_df.sort_values(by='Population (2020)', ascending=True)[:30]

# Sort by GDP and select the top 10 states
top_30_gdp = merged_df.sort_values(by='GDP (MXN)', ascending=True)[:30]

# %%
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5))

# Seaborn barplot for population density
sns.barplot(x=top_20_pop.index, y='Population (2020)', data=top_20_pop, ax=ax1, palette='Blues')
ax1.set_title('Top 20 Mexican states by population density')
ax1.set_xlabel('State')
ax1.set_ylabel('Population density (people/km²)')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, fontsize=8)

# Seaborn barplot for GDP
sns.barplot(x=top_20_gdp.index, y='GDP (MXN)', data=top_20_gdp, ax=ax2, palette='Greens')
ax2.set_title('Top 20 Mexican states by GDP')
ax2.set_xlabel('State')
ax2.set_ylabel('GDP (millions of USD)')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, fontsize=8)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5))
# Seaborn barplot for population density
sns.barplot(x=top_20_pop.index, y='Population (2020)', data=top_20_pop, ax=ax1, palette=sns.color_palette("Blues_r", n_colors=len(top_20_pop)))
ax1.set_title('Top 10 Mexican states by population density')
ax1.set_xlabel('State')
ax1.set_ylabel('Population density (people/km²)')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, fontsize=8)
# Seaborn barplot for GDP
sns.barplot(x=top_20_gdp.index, y='GDP (MXN)', data=top_20_gdp, ax=ax2, palette=sns.color_palette("Greens_r", n_colors=len(top_20_gdp)))
ax2.set_title('Top 10 Mexican states by GDP')
ax2.set_xlabel('State')
ax2.set_ylabel('GDP (millions of USD)')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, fontsize=8)
plt.tight_layout()
plt.show()
